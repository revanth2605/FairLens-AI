# %% [markdown]
# # EDA\n
# This notebook contains exploratory data analysis for the dataset.

# %%
import pandas as pd\n
print('Load and inspect your CSVs here')\n
